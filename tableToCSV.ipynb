# %%
import numpy as np
from matplotlib import pyplot as plt
x = np.arange(0, 10)
y = x + 1
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis caption")
plt.plot(x, y, linestyle='-', color='b', marker='o')
plt.show()

# %%
# !pip install camelot-py[cv]
#Done

# %%
import camelot
tables = camelot.read_pdf('C:/Users/Jigar/Desktop/COLLEGE/Semester_5/ML/ML-Stuff/table.pdf')
# Out:
# ---------------------------------------------------------------------------
# DeprecationError                          Traceback (most recent call last)
# Cell In[8], line 2
#       1 import camelot
# ----> 2 tables = camelot.read_pdf('C:/Users/Jigar/Desktop/COLLEGE/Semester_5/ML/ML-Stuff/table.pdf')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\camelot\io.py:113, in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     111 p = PDFHandler(filepath, pages=pages, password=password)
#     112 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 113 tables = p.parse(
#     114     flavor=flavor,
#     115     suppress_stdout=suppress_stdout,
#     116     layout_kwargs=layout_kwargs,
#     117     **kwargs
#     118 )
#     119 return tables
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\camelot\handlers.py:169, in PDFHandler.parse(self, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     167 with TemporaryDirectory() as tempdir:
#     168     for p in self.pages:
# --> 169         self._save_page(self.filepath, p, tempdir)
#     170     pages = [os.path.join(tempdir, f"page-{p}.pdf") for p in self.pages]
#     171     parser = Lattice(**kwargs) if flavor == "lattice" else Stream(**kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\camelot\handlers.py:108, in PDFHandler._save_page(self, filepath, page, temp)
#      95 """Saves specified page from PDF into a temporary directory.
#      96
#      97 Parameters
#    (...)
#     105
#     106 """
#     107 with open(filepath, "rb") as fileobj:
# --> 108     infile = PdfFileReader(fileobj, strict=False)
#     109     if infile.isEncrypted:
#     110         infile.decrypt(self.password)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\PyPDF2\_reader.py:1974, in PdfFileReader.__init__(self, *args, **kwargs)
#    1973 def __init__(self, *args: Any, **kwargs: Any) -> None:
# -> 1974     deprecation_with_replacement("PdfFileReader", "PdfReader", "3.0.0")
#    1975     if "strict" not in kwargs and len(args) < 2:
#    1976         kwargs["strict"] = True  # maintain the default
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\PyPDF2\_utils.py:369, in deprecation_with_replacement(old_name, new_name, removed_in)
#     363 def deprecation_with_replacement(
#     364     old_name: str, new_name: str, removed_in: str = "3.0.0"
#     365 ) -> None:
#     366     """
#     367     Raise an exception that a feature was already removed, but has a replacement.
#     368     """
# --> 369     deprecation(DEPR_MSG_HAPPENED.format(old_name, removed_in, new_name))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\PyPDF2\_utils.py:351, in deprecation(msg)
#     350 def deprecation(msg: str) -> None:
# --> 351     raise DeprecationError(msg)
#
# DeprecationError: PdfFileReader is deprecated and was removed in PyPDF2 3.0.0. Use PdfReader instead.

# %%
# !pip install PdfReader
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting PdfReader
#   Downloading pdfreader-0.1.15-py3-none-any.whl.metadata (4.3 kB)
# Collecting bitarray>=1.1.0 (from PdfReader)
#   Downloading bitarray-2.9.2-cp312-cp312-win_amd64.whl.metadata (35 kB)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from PdfReader) (10.2.0)
# Collecting pycryptodome>=3.9.9 (from PdfReader)
#   Downloading pycryptodome-3.20.0-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from PdfReader) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\jigar\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.1->PdfReader) (1.16.0)
# Downloading pdfreader-0.1.15-py3-none-any.whl (135 kB)
#    ---------------------------------------- 0.0/135.6 kB ? eta -:--:--
#    ---------------------------------------- 0.0/135.6 kB ? eta -:--:--
#    --------------------------- ------------ 92.2/135.6 kB ? eta -:--:--
#    ------------------------------ --------- 102.4/135.6 kB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 135.6/135.6 kB 1.1 MB/s eta 0:00:00
# Downloading bitarray-2.9.2-cp312-cp312-win_amd64.whl (126 kB)
#    ---------------------------------------- 0.0/126.2 kB ? eta -:--:--
#    ------------------- -------------------- 61.4/126.2 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 126.2/126.2 kB 1.5 MB/s eta 0:00:00
# Downloading pycryptodome-3.20.0-cp35-abi3-win_amd64.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    - -------------------------------------- 0.1/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.8 MB 2.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/1.8 MB 3.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/1.8 MB 3.2 MB/s eta 0:00:01
#    ------ --------------------------------- 0.3/1.8 MB 1.3 MB/s eta 0:00:02
#    ------ --------------------------------- 0.3/1.8 MB 1.3 MB/s eta 0:00:02
#    -------- ------------------------------- 0.4/1.8 MB 1.2 MB/s eta 0:00:02
#    --------- ------------------------------ 0.4/1.8 MB 1.2 MB/s eta 0:00:02
#    ------------ --------------------------- 0.6/1.8 MB 1.3 MB/s eta 0:00:01
#    --------------- ------------------------ 0.7/1.8 MB 1.5 MB/s eta 0:00:01
#    ------------------ --------------------- 0.8/1.8 MB 1.6 MB/s eta 0:00:01
#    --------------------- ------------------ 0.9/1.8 MB 1.7 MB/s eta 0:00:01
#    ------------------------ --------------- 1.1/1.8 MB 1.8 MB/s eta 0:00:01
#    ------------------------- -------------- 1.1/1.8 MB 1.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 1.3/1.8 MB 1.9 MB/s eta 0:00:01
#    --------------------------------- ------ 1.5/1.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 1.6/1.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 2.2 MB/s eta 0:00:00
# Installing collected packages: bitarray, pycryptodome, PdfReader
# Successfully installed PdfReader-0.1.15 bitarray-2.9.2 pycryptodome-3.20.0
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: C:\Users\Jigar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
